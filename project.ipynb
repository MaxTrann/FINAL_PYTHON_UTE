# %% [markdown]
# # 2.1 Student Performance Factors
#
# ## Lịch sử và Nguồn gốc
# - **Tác giả:** Lai Nguyễn
# - **Ngày tạo:** 2/9/2024
#
# ## Công dụng
# Bộ dữ liệu được sử dụng phổ biến để:
# - **Phân tích hiệu suất học tập:** Tìm hiểu các yếu tố chính ảnh hưởng đến điểm số của học sinh.
# - **Ứng dụng trong học máy (Machine Learning):** Huấn luyện mô hình dự đoán điểm số hoặc phân loại học sinh dựa trên các yếu tố đầu vào.
# - **Nghiên cứu giáo dục:** Đưa ra các chính sách hoặc giải pháp cải thiện chất lượng giảng dạy và học tập.
#
# ## Danh sách các đặc trưng
# | **Tên đặc trưng**         | **Mô tả**                                                        | **Giá trị có thể**                                |
# |---------------------------|------------------------------------------------------------------|--------------------------------------------------|
# | Hours_Studied            | Số giờ học mỗi tuần                                             | Số nguyên dương                                  |
# | Attendance               | Tỷ lệ tham gia lớp học                                          | 0% đến 100%                                      |
# | Parental_Involvement     | Mức độ tham gia của phụ huynh                                    | Low, Medium, High                                |
# | Access_to_Resources      | Sự sẵn có của các tài nguyên giáo dục                           | Low, Medium, High                                |
# | Extracurricular_Activities | Tham gia các hoạt động ngoại khóa                              | Yes, No                                          |
# | Sleep_Hours              | Số giờ ngủ trung bình mỗi đêm                                   | Số nguyên dương                                  |
# | Previous_Scores          | Điểm số từ các kỳ thi trước                                     | Số thực từ 0 đến 100                             |
# | Motivation_Level         | Mức độ động lực học tập                                         | Low, Medium, High                                |
# | Internet_Access          | Sự sẵn có của kết nối internet                                  | Yes, No                                          |
# | Tutoring_Sessions        | Số buổi học thêm mỗi tháng                                      | Số nguyên không âm                               |
# | Family_Income            | Mức thu nhập gia đình                                           | Low, Medium, High                                |
# | Teacher_Quality          | Chất lượng của giáo viên                                        | Low, Medium, High                                |
# | School_Type              | Loại trường học mà học sinh theo học                           | Public, Private                                  |
# | Peer_Influence           | Ảnh hưởng của bạn bè đến hiệu suất học tập                      | Positive, Neutral, Negative                      |
# | Physical_Activity        | Số giờ hoạt động thể chất trung bình mỗi tuần                  | Số nguyên không âm                               |
# | Learning_Disabilities    | Sự hiện diện của các khó khăn học tập                           | Yes, No                                          |
# | Parental_Education_Level | Trình độ học vấn cao nhất của phụ huynh                         | High School, College, Postgraduate              |
# | Distance_from_Home       | Khoảng cách từ nhà đến trường                                   | Near, Moderate, Far                              |
# | Gender                   | Giới tính của học sinh                                         | Male, Female                                     |
# | Exam_Score               | Điểm thi cuối kỳ                                               | Số thực từ 0 đến 100                             |
#
# ## Kiểu dữ liệu
# - **Số nguyên (Integer):** `Hours_Studied`, `Sleep_Hours`, `Tutoring_Sessions`, `Physical_Activity`.
# - **Số thực (Float):** `Attendance`, `Previous_Scores`, `Exam_Score`.
# - **Chuỗi (String):** `Parental_Involvement`, `Access_to_Resources`, `Motivation_Level`, `Family_Income`, `Teacher_Quality`, `School_Type`, `Peer_Influence`, `Parental_Education_Level`, `Distance_from_Home`, `Gender`.
# - **Boolean (Đúng/Sai):** `Extracurricular_Activities`, `Internet_Access`, `Learning_Disabilities`.
#
# ## Mục tiêu
# Bộ dữ liệu này được thiết kế để hỗ trợ trong lĩnh vực giáo dục bằng cách:
# - **Phân tích hiệu suất học tập:** Xác định mối quan hệ giữa các yếu tố như thời gian học, giờ ngủ, hoặc mức độ tham gia hoạt động ngoại khóa với điểm thi.
# - **Phát triển mô hình dự đoán:** Xây dựng các mô hình để dự đoán thành tích học tập của học sinh dựa trên các yếu tố ảnh hưởng.
# - **Cải thiện hệ thống giáo dục:** Đưa ra các gợi ý cải thiện về chất lượng giáo dục, phương pháp dạy học, và hỗ trợ cá nhân hóa cho học sinh.
# - **Nghiên cứu học thuật:** Hỗ trợ nghiên cứu về hành vi và thói quen học tập của học sinh trong các bối cảnh khác nhau.
#
# ## Lĩnh vực
# - **Giáo dục:** Tối ưu hóa phương pháp giảng dạy và hỗ trợ học sinh.
# - **Khoa học dữ liệu:** Ứng dụng trong phân tích và xây dựng các mô hình học máy.
# - **Tâm lý học giáo dục:** Hiểu rõ hơn các yếu tố ảnh hưởng đến động lực học tập và kết quả học tập.
# - **Xã hội học:** Phân tích mối liên hệ giữa điều kiện kinh tế xã hội và hiệu suất học tập.
#
# ## Hạn chế
# 1. **Dữ liệu không đầy đủ:**
#    - Thiếu thông tin quan trọng về các yếu tố như sức khỏe tinh thần, căng thẳng, hoặc cảm xúc học tập.
#    - Không có dữ liệu theo dõi dài hạn về ảnh hưởng của các yếu tố lên hiệu suất học tập.
# 2. **Chủ quan trong tự báo cáo:**
#    - Nhiều dữ liệu như số giờ học, động lực, hoặc mức độ tham gia hoạt động ngoại khóa dựa trên tự đánh giá, dễ dẫn đến sai lệch.
# 3. **Thiếu sự đại diện:**
#    - Bộ dữ liệu có thể chỉ đại diện cho một nhóm học sinh cụ thể, làm giảm tính khái quát khi áp dụng vào các nhóm khác.
# 4. **Không chuẩn hóa:**
#    - Các giá trị không thống nhất về đơn vị đo lường hoặc phạm vi (ví dụ: cách đo thời gian hoặc mức độ ảnh hưởng).
#
# ## Khiếm khuyết
# 1. **Hạn chế mẫu học sinh:**
#    - Chỉ bao gồm một nhóm đối tượng cụ thể, như trường công hoặc tư, hoặc khu vực nhất định, làm giảm tính khái quát.
# 2. **Thiếu các yếu tố môi trường và xã hội:**
#    - Không có thông tin về sự hỗ trợ từ gia đình, điều kiện sống, hoặc áp lực xã hội ảnh hưởng đến học sinh.
# 3. **Không đánh giá chất lượng dữ liệu:**
#    - Bộ dữ liệu thiếu các thông tin về quy trình thu thập, làm khó khăn trong việc đánh giá độ chính xác và độ tin cậy.
# 4. **Giới hạn về thời gian:**
#    - Dữ liệu chỉ ghi nhận tại một thời điểm cố định, không phản ánh xu hướng hoặc thay đổi dài hạn.

# %% [markdown]
# # 2. Thực hiện xử lí dữ liệu
# ## Importing library

# %%
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from dataCRUD import dataProcessing
from dataCleaning import *
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning) #bỏ qua các dòng warning

# %% [markdown]
# ## Đọc dữ liệu từ file CSV và chuẩn bị thao tác với dataset

# %%
data = pd.read_csv('visual_StudentPerformanceFactors.csv')
Data_Frame = dataProcessing('StudentPerformanceFactors.csv')
Cleaning_Data = dataCleaner('StudentPerformanceFactors.csv')
outfileDataCleaned = "cleaned_StudentPerformanceFactors.csv"

# %% [markdown]
# ## In dữ liệu

# %%
Data_Frame.outputData()
# Out:
# Trang 1/7:
#                 0           1                     2                    3   \
# 0    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources
# 1               23          84                   Low                 High
# 2               19          64                   Low               Medium
# 3               24          98                Medium               Medium
# 4               29          89                   Low               Medium
# ..             ...         ...                   ...                  ...
# 995             14          81                Medium               Medium
# 996             18          95                Medium                 High
# 997             31          96                Medium               Medium
# 998             24          71                   Low                 High
# 999             17          78                   Low               Medium
#
#                              4            5                6   \
# ...

# %% [markdown]
# ## Column Descriptions
# **Hours_Studied**: Number of hours spent studying per week.
#
# **Attendance**: Percentage of classes attended.
#
# **Parental_Involvement**: Level of parental involvement in the student's education (Low, Medium, High).
#
# **Access_to_Resources**: Availability of educational resources (Low, Medium, High).
#
# **Extracurricular_Activities**: Participation in extracurricular activities (Yes, No).
#
# **Sleep_Hours**: Average number of hours of sleep per night.
#
# **Previous_Scores**: Scores from previous exams.
#
# **Motivation_Level**: Student's level of motivation (Low, Medium, High).
#
# **Internet_Access**: Availability of internet access (Yes, No).
#
# **Tutoring_Sessions**: Number of tutoring sessions attended per month.
#
# **Family_Income**: Family income level (Low, Medium, High).
#
# **Teacher_Quality**: Quality of the teachers (Low, Medium, High).
#
# **School_Type**: Type of school attended (Public, Private).
#
# **Peer_Influence**: Influence of peers on academic performance (Positive, Neutral, Negative).
#
# **Physical_Activity**: Average number of hours of physical activity per week.
#
# **Learning_Disabilities**: Presence of learning disabilities (Yes, No).
#
# **Parental_Education_Level**: Highest education level of parents (High School, College, Postgraduate).
#
# **Distance_from_Home**: Distance from home to school (Near, Moderate, Far).
#
# **Gender**:	Gender of the student (Male, Female).
#
# **Exam_Score**: Final exam score.

# %%
data = Data_Frame.getData()
column_names = ["Hours_Studied", "Attendance", "Parental_Involvement", "Access_to_Resources", 
                "Extracurricular_Activities", "Sleep_Hours", "Previous_Scores", "Motivation_Level", 
                "Internet_Access", "Tutoring_Sessions", "Family_Income", "Teacher_Quality", 
                "School_Type", "Peer_Influence", "Physical_Activity", "Learning_Disabilities", 
                "Parental_Education_Level", "Distance_from_Home", "Gender", "Exam_Score"]
data = pd.DataFrame(data, columns=column_names)
data
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0     Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources
# 1                23          84                   Low                 High
# 2                19          64                   Low               Medium
# 3                24          98                Medium               Medium
# 4                29          89                   Low               Medium
# ...             ...         ...                   ...                  ...
# 6603             25          69                  High               Medium
# 6604             23          76                  High               Medium
# 6605             20          90                Medium                  Low
# 6606             10          86                  High                 High
# 6607             15          67                Medium                  Low
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Data_Crud

# %% [markdown]
# ### Thêm bản ghi dữ liệu

# %%
while True:
    new_data = input("Enter new comma-separated values' record: ").split(',') #13,91,Low,Medium,No,6,90,Medium,Yes,1,High,Medium,Public,Negative,2,Yes,High School,Moderate,Female,65

    if len(new_data) == len(Data_Frame.getSampleData()):
        Data_Frame.addData(new_data)
        break
    else:
        print ("Invalid field count. Enter data with correct field count.")
# Out:
# Dữ liệu đã được thêm!

# %% [markdown]
# ### Cập nhật bản ghi

# %%
while True:
    Updated_Index = input("Input updated data's index: ") #28
    if Updated_Index.isdigit():
        Updated_Index = int(Updated_Index)  #12,91,Low,Medium,No,6,90,Medium,Yes,1,High,Medium,Public,Negative,2,Yes,High School,Moderate,Female,65
        if 0 < Updated_Index < len(Data_Frame.getData()):
            break
        else:
            print ("\nInvalid input. Please try again")
    else:
        print ("\nInvalid input. Please enter a number.")
while True:
    Updated_Data = input("Enter new comma-separated values' record: ").split(',')
    if len(Updated_Data) == len(Data_Frame.getSampleData()):
        Data_Frame.updateData(Updated_Index, Updated_Data)
        break
    else:
        print ("Invalid field count. Please enter data with correct field count.")
# Out:
# Dữ liệu đã được cập nhật!

# %% [markdown]
# ### Xóa bản ghi

# %%
Deleted_Index = input("Input deleted data's index: ")   # 1
if Deleted_Index.isdigit(): 
    Deleted_Index = int(Deleted_Index)
    if 0 < Deleted_Index < len(Data_Frame.getData()):
        Data_Frame.deleteData(Deleted_Index)
    else:
        print ("Invalid input. Please enter a number.")
else:
    print ("Invalid input. Please enter a number.")
# Out:
# Dữ liệu đã được xóa!

# %% [markdown]
# ### Lưu bản ghi

# %%
Data_Frame.saveData()
# Out:
# Dữ liệu đã được lưu thành công!

# %% [markdown]
# ## Data_Cleaning

# %% [markdown]
# ### Hàm 1: Thống kê dữ liệu của file

# %%
Cleaning_Data.aggregateData()
# Out:
# Thống kê các giá trị có trong file:
#
# Thông tin về cột Hours_Studied':
# Hours_Studied
# 20    465
# 19    441
# 21    431
# 23    411
# 22    402
# 18    401
# 17    381
# 24    357
# 16    351
# 15    315
# 25    289
# 14    269
# 26    263
# 27    229
# 13    218
# 12    192
# 28    171
# 11    146
# 29    134
# 30    123
# 10     94
# 9      86
# 31     77
# 8      58
# 32     54
# 7      51
# 33     40
# 34     29
# 5      21
# 35     20
# 4      17
# 6      17
# 3      12
# 36     11
# 38      7
# 39      7
# 2       6
# 37      6
# 1       3
# 43      1
# 44      1
# Name: count, dtype: int64
#
# Thông tin về cột Attendance':
# Attendance
# 67     190
# 98     187
# 76     185
# 77     184
# 64     182
# 94     180
# 91     175
# 84     175
# 79     175
# 82     173
# 69     170
# 68     170
# 80     169
# 96     168
# 73     168
# 81     168
# 93     167
# 72     167
# 74     165
# 78     165
# 61     164
# 95     163
# 71     162
# 89     162
# 97     161
# 70     161
# ...

# %% [markdown]
# ### Hàm 2: Sắp xếp dữ liệu theo cột

# %%
while True:
    try:
        col_index = int(input("Input the column that you want to sort: "))
        if 0 <= col_index < len(Data_Frame.getSampleData()):
            reverse = input("Sort in ascending order? (y/n): ").lower() == 'y'
            Cleaning_Data.sortData(col_index=col_index, reverse=reverse)
            print ("Data is processed")
            break
        else:
            print ("\nInvalid Input. Please choose again.")
            continue
    except ValueError:
        print ("\nInvalid input. Please enter a number")
Cleaning_Data.data.to_csv(outfileDataCleaned, index=False)
print("Data is saved in new CSV file.")
# Out:
# Dữ liệu đã được sắp xếp!
# Data is processed
# Data is saved in new CSV file.

# %% [markdown]
# ### Hàm 3:Lấy dữ liệu thông qua chỉ số dòng

# %%
while True:
    try:
        Get_Index = int(input("Enter row index: ")) #1
        if 0 < Get_Index < len(Data_Frame.getData()):
            print(Cleaning_Data.getDataByIndex(Get_Index))
            break
        else:
            print ("\nInvalid Input. Please choose again.")
            continue
    except ValueError:
        print ("\nInvalid Input. Please enter a number.")
# Out:
# Hours_Studied                          16
# Attendance                             60
# Parental_Involvement               Medium
# Access_to_Resources                   Low
# Extracurricular_Activities             No
# Sleep_Hours                             8
# Previous_Scores                        87
# Motivation_Level                      Low
# Internet_Access                       Yes
# Tutoring_Sessions                       0
# Family_Income                         Low
# Teacher_Quality                       Low
# School_Type                        Public
# Peer_Influence                   Positive
# Physical_Activity                       5
# Learning_Disabilities                  No
# Parental_Education_Level      High School
# Distance_from_Home                   Near
# Gender                               Male
# Exam_Score                             60
# Name: 5091, dtype: object

# %% [markdown]
# ### Hàm 4: Tìm kiếm dữ liệu thông qua keyword, và tên cột

# %%
while True:
    ColName = input("Enter Column Name: ")  #Hours_Studied
    if ColName in Cleaning_Data.data.columns:
        keyword = input("Enter keyword: ")  #19
        Cleaning_Data.searchData(keyword, ColName)
        break
    else:
        print ("\nInvalid Column Name. Please try again.")
# Out:
# Kết quả tìm kiếm:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 2641             19          60                 High                High
# 4695             19          60               Medium              Medium
# 573              19          60               Medium                High
# 5009             19          60               Medium                 Low
# 290              19          60               Medium                High
# ...             ...         ...                  ...                 ...
# 1740             19         100               Medium                 Low
# 4121             19         100               Medium                High
# 6310             19         100                 High                 Low
# 3737             19         100               Medium                 Low
# 4705             19         100                  Low                High
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ### Hàm 5: Hàm để loại bỏ những dòng bị thiếu dữ liệu NULL (NaN)

# %%
Cleaning_Data.deleteMissingData()
print ("\nData is processed")
Cleaning_Data.data.to_csv(outfileDataCleaned, index=False)
print("Data is saved in new CSV file.")
# Out:
# Data is processed
# Data is saved in new CSV file.

# %% [markdown]
# ### Hàm 6: Điền giá trị vào ô trống trong một cột

# %%
while True:
    ColName = input("Enter Column Name: ")  #Parental_Education_Level
    if ColName in Cleaning_Data.data.columns:
        value = input("Enter Filling Value: ")  #Primary
        Cleaning_Data.fillMissingData(ColName, value)
        print ("\nData is processed")
        break
    else:
        print ("\nInvalid Column Name. Please try again.")
Cleaning_Data.data.to_csv(outfileDataCleaned, index=False)
print("Data is saved in new CSV file.")
# Out:
# Thêm giá trị Primary vào Parental_Education_Level thành công!
#
# Data is processed
# Data is saved in new CSV file.

# %% [markdown]
# ### Hàm 7: Chuẩn hóa dữ liệu

# %%
while True:
    Standardized_Col = input("Input column you want to standardize: ")  #Gender
    if Standardized_Col in Cleaning_Data.data.columns:
        Valid_List = input("Enter valid values separated by comma: ").split(',')    #male, female
        Cleaning_Data.cleanCategoryData(Standardized_Col, Valid_List)
        print ("\nData is processed")
        break
    else:
        print ("\nInvalid Column Name. Please try again.")
Cleaning_Data.data.to_csv(outfileDataCleaned, index=False)
print("Data is saved in new CSV file.")
# Out:
# Data is processed
# Data is saved in new CSV file.

# %% [markdown]
# ### Hàm 8: Xử lí các số liệu ngoại lai

# %%
Cleaning_Data.deleteOutliers()
Cleaning_Data.data.to_csv(outfileDataCleaned, index=False)
print("Data is saved in new CSV file.")
# Out:
# Data is saved in new CSV file.

# %% [markdown]
# ## VISUALIZATION

# %%
sns.set(style="whitegrid") #tạo lưới khoảng trắng

# %% [markdown]
# ### Biểu đồ phân phối điểm thi

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Exam_Score'], kde=True, bins=30, color='skyblue')
plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Biểu đồ điểm thi theo mức độ tham gia của phụ huynh

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Parental_Involvement', y='Exam_Score', data=data, palette='pastel')
plt.title("Exam Score by Parental Involvement Level")
plt.xlabel("Parental Involvement")
plt.ylabel("Exam Score")
plt.show()

# %% [markdown]
# ### Biểu đồ số giờ học và điểm thi

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Hours_Studied', y='Exam_Score', data=data, hue='Gender', palette='viridis', s=60)
plt.title("Hours Studied vs Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.show()

# %% [markdown]
# ### Biểu đồ điểm thi theo thu nhập gia đình

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Family_Income', y='Exam_Score', data=data, palette='muted')
plt.title("Exam Score by Family Income Level")
plt.xlabel("Family Income Level")
plt.ylabel("Exam Score")
plt.show()

# %% [markdown]
# ### Biểu đồ mức độ truy cập internet và điểm thi trung bình

# %%
plt.figure(figsize=(10, 6))
internet_avg_score = data.groupby('Internet_Access')['Exam_Score'].mean().reset_index()
sns.barplot(x='Internet_Access', y='Exam_Score', data=internet_avg_score, palette='coolwarm')
plt.title("Average Exam Score by Internet Access")
plt.xlabel("Internet Access")
plt.ylabel("Average Exam Score")
plt.show()

# %% [markdown]
# ### Biểu đồ hoạt động ngoại khóa và tỷ lệ học sinh tham gia

# %%
extra_gender = data.groupby(['Extracurricular_Activities', 'Gender']).size().unstack()
extra_gender.plot(kind='bar', stacked=True, color=['#3498db', '#e74c3c'], figsize=(10, 6))
plt.title("Participation in Extracurricular Activities by Gender")
plt.xlabel("Extracurricular Activities")
plt.ylabel("Count")
plt.legend(title="Gender")
plt.show()

# %% [markdown]
# ### Biểu đồ phân phối loại trường học

# %%
plt.figure(figsize=(8, 8))
school_type_counts = data['School_Type'].value_counts()
plt.pie(school_type_counts, labels=school_type_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Distribution of School Type")
plt.show()

# %% [markdown]
# ### Biểu đồ ma trận tương quan các biến số học tập

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = data.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Numeric Study Factors")
plt.show()

# %% [markdown]
# ### Biểu đồ điểm thi trung bình theo mức chất lượng giáo viên

# %%
plt.figure(figsize=(10, 6))
teacher_quality_avg_score = data.groupby('Teacher_Quality')['Exam_Score'].mean().reset_index().sort_values(by='Teacher_Quality')
sns.lineplot(x='Teacher_Quality', y='Exam_Score', data=teacher_quality_avg_score, marker='o', color='teal')
plt.title("Average Exam Score by Teacher Quality")
plt.xlabel("Teacher Quality")
plt.ylabel("Average Exam Score")
plt.show()

# %% [markdown]
# ### Biểu đồ điểm thi trung bình theo trình độ học vấn của phụ huynh

# %%
plt.figure(figsize=(10, 6))
parental_education_avg_score = data.groupby('Parental_Education_Level')['Exam_Score'].mean().reset_index()
sns.barplot(x='Parental_Education_Level', y='Exam_Score', data=parental_education_avg_score, palette='viridis')
plt.title("Average Exam Score by Parental Education Level")
plt.xlabel("Parental Education Level")
plt.ylabel("Average Exam Score")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # GUI
# ## Giao diện Data Execution Options
# ![image-3.png](attachment:image-3.png)
# ## Giao diện phân trang
# ![image.png](attachment:image.png)
# ## Giao diện Data Cleaning Options
# ![image-2.png](attachment:image-2.png)
